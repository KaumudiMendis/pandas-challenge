# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
# Read School Data File and store into Pandas DataFrames
school_data_df = pd.read_csv(school_data_to_load, encoding="utf-8")
school_data_df.head(50)
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# 14         14     Thomas High School   Charter  1635  1043130

# %%
# Read Student Data File and store into Pandas DataFrames

student_data_df = pd.read_csv(student_data_to_load, encoding="utf-8")
student_data_df.head(7)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84
# 5             94          94
# 6             82          80

# %%
# Combine the data into a single dataset.  

school_data_complete_df= pd.merge(student_data_df, school_data_df, how="left", on=["school_name", "school_name"])
school_data_complete_df.head(5)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total number of schools
#Bring up all unique school names into a data frame. Length of that unique school_name data frame is the 
#total number of schools (found matching with school_data_to_load which is 15 unique school names in the list ) unique_school_name_df=school_data_complete_df["school_name"].unique()

total_number_of_schools=len(unique_school_name_df)
total_number_of_schools
# Out:
# 15

# %%
#_Calculate_the_total_number_of_students

total_number_of_students=school_data_complete_df["Student ID"].count()
total_number_of_students
# Out:
# 39170

# %%
#Calculate the total budget

total_budget=school_data_df["budget"].sum()
total_budget=f"${total_budget:,.0f}"
total_budget
# Out:
# '$24,649,428'

# %%
# Calculate the average math score

average_math_score=round(school_data_complete_df["math_score"].mean())
average_math_score
# Out:
# 79

# %%
#Calculate the average reading score

average_reading_score=round(school_data_complete_df["reading_score"].mean())
average_reading_score
# Out:
# 82

# %%
# Calculate the percentage of students with a passing math score (70 or greater)
##_Find_the_students_have_a_maths_score_>=70_from_merged_data_frame_-_school_data_complete_df
##CalculateTotal_number_of_students_passed_is_counted
##_Percentage_of_passing_math_score_=_total_students_>=70/total_students.

# %%
stu_passing_math_score_df=school_data_complete_df.loc[school_data_complete_df["math_score"]>=70]
Total_stu_passing_math_score_df=stu_passing_math_score_df["Student ID"].count()
Percentage_of_passing_math_score=(Total_stu_passing_math_score_df/total_number_of_students)*100
Percentage_of_passing_math_score=f"{Percentage_of_passing_math_score:.2f}"
Percentage_of_passing_math_score
# Out:
# '74.98'

# %%
# Calculate the percentage of students with a passing reading score (70 or greater)
## Find the students have a reading score >=70 from merged data frame - school data complete df
## Total number of students passed is counted
## Percentage of passing math score = total students >=70/total students.

# %%
stu_passing_reading_score_df=school_data_complete_df.loc[school_data_complete_df["reading_score"]>=70]
Total_stu_passing_reading_score_df=stu_passing_reading_score_df["Student ID"].count()
Percentage_of_passing_reading_score=(Total_stu_passing_reading_score_df/total_number_of_students)*100
Percentage_of_passing_reading_score=f"{Percentage_of_passing_reading_score:.2f}"
Percentage_of_passing_reading_score
# Out:
# '85.81'

# %%
# Calculate the percentage of students who passed math and reading (% Overall Passing)

Overall_Passing= school_data_complete_df.loc[(school_data_complete_df["math_score"]>=70) & 
                 (school_data_complete_df["reading_score"]>=70)]["Student ID"].count()/total_number_of_students*100
Overall_Passing=f"{Overall_Passing:.2f}"   
Overall_Passing
# Out:
# '65.17'

# %% [markdown]
# ### District Summary Data Frame

# %%
# Create a dataframe to hold the above results
district_summary_df=pd.DataFrame({
"Total Schools":total_number_of_schools,
"Total Students":f"{total_number_of_students:,}",
"Total Budget":total_budget,
"Average Math Score":average_math_score,
"Average Reading Score":average_reading_score,
"% Passing Math":Percentage_of_passing_math_score,
"% Passing Reading":Percentage_of_passing_reading_score,
"% Overall Passin":Overall_Passing
},index=[0])
district_summary_df
# Out:
#    Total Schools Total Students Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428                  79
#
#    Average Reading Score % Passing Math % Passing Reading % Overall Passin
# 0                     82          74.98             85.81            65.17

# %%
# Optional: give the displayed data cleaner formatting

#district_summary_df=pd.DataFrame({
#"Total Schools":f"{total_number_of_schools:,}",
#"Total Students":f"{total_number_of_students:,}",
#"Total Budget":f"${int(total_budget_mil):,}",
#"Average Math Score":average_math_score,
#"Average Reading Score":average_reading_score,
#"% Passing Math":Percentage_of_passing_math_score,
#"% Passing Reading":Percentage_of_passing_reading_score,
#"% Overall Passin":Overall_Passing
#},index=[0])
#district_summary_df

# %% [markdown]
# # School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#Create an overview table that summarizes key metrics about each school, including:

# Per Student Budget
# Average Math Score
# Average Reading Score
# % Passing Math
# % Passing Reading
# % Overall Passing (The percentage of students that passed math and reading.)

# %%
#See any data to clean
school_data_complete_df.tail(2)
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID     type  size   budget
# 39168             99          90         14  Charter  1635  1043130
# 39169             95          75         14  Charter  1635  1043130

# %%
#Group by school name and type
school_name_df=school_data_complete_df.groupby(['school_name','type']).count()
school_name_df
# Out:
#                                 Student ID  student_name  gender  grade  \
# school_name           type
# Bailey High School    District        4976          4976    4976   4976
# Cabrera High School   Charter         1858          1858    1858   1858
# Figueroa High School  District        2949          2949    2949   2949
# Ford High School      District        2739          2739    2739   2739
# Griffin High School   Charter         1468          1468    1468   1468
# Hernandez High School District        4635          4635    4635   4635
# Holden High School    Charter          427           427     427    427
# Huang High School     District        2917          2917    2917   2917
# Johnson High School   District        4761          4761    4761   4761
# Pena High School      Charter          962           962     962    962
# Rodriguez High School District        3999          3999    3999   3999
# Shelton High School   Charter         1761          1761    1761   1761
# Thomas High School    Charter         1635          1635    1635   1635
# Wilson High School    Charter         2283          2283    2283   2283
# Wright High School    Charter         1800          1800    1800   1800
#
#                                 reading_score  math_score  School ID  size  \
# school_name           type
# Bailey High School    District           4976        4976       4976  4976
# Cabrera High School   Charter            1858        1858       1858  1858
# Figueroa High School  District           2949        2949       2949  2949
# Ford High School      District           2739        2739       2739  2739
# Griffin High School   Charter            1468        1468       1468  1468
# Hernandez High School District           4635        4635       4635  4635
# Holden High School    Charter             427         427        427   427
# Huang High School     District           2917        2917       2917  2917
# Johnson High School   District           4761        4761       4761  4761
# Pena High School      Charter             962         962        962   962
# Rodriguez High School District           3999        3999       3999  3999
# Shelton High School   Charter            1761        1761       1761  1761
# Thomas High School    Charter            1635        1635       1635  1635
# Wilson High School    Charter            2283        2283       2283  2283
# Wright High School    Charter            1800        1800       1800  1800
#
#                                 budget
# school_name           type
# Bailey High School    District    4976
# Cabrera High School   Charter     1858
# Figueroa High School  District    2949
# Ford High School      District    2739
# Griffin High School   Charter     1468
# Hernandez High School District    4635
# Holden High School    Charter      427
# Huang High School     District    2917
# Johnson High School   District    4761
# Pena High School      Charter      962
# Rodriguez High School District    3999
# Shelton High School   Charter     1761
# Thomas High School    Charter     1635
# Wilson High School    Charter     2283
# Wright High School    Charter     1800

# %%
#Calculate total Students per school name
total_student_df=school_name_df['Student ID']
total_student_df
# Out:
# school_name            type
# Bailey High School     District    4976
# Cabrera High School    Charter     1858
# Figueroa High School   District    2949
# Ford High School       District    2739
# Griffin High School    Charter     1468
# Hernandez High School  District    4635
# Holden High School     Charter      427
# Huang High School      District    2917
# Johnson High School    District    4761
# Pena High School       Charter      962
# Rodriguez High School  District    3999
# Shelton High School    Charter     1761
# Thomas High School     Charter     1635
# Wilson High School     Charter     2283
# Wright High School     Charter     1800
# Name: Student ID, dtype: int64

# %%
# Total School Budget
#total_school_budget=school_data_df.set_index('school_name')['budget']
total_school_budget_df=school_data_complete_df.groupby(['school_name','budget']).mean()
total_school_budget_df
# Out:
#                                Student ID  reading_score  math_score  \
# school_name           budget
# Bailey High School    3124928     20358.5      81.033963   77.048432
# Cabrera High School   1081356     16941.5      83.975780   83.061895
# Figueroa High School  1884411      4391.0      81.158020   76.711767
# Ford High School      1763916     36165.0      80.746258   77.102592
# Griffin High School   917500      12995.5      83.816757   83.351499
# Hernandez High School 3022020      9944.0      80.934412   77.289752
# Holden High School    248087      23060.0      83.814988   83.803279
# Huang High School     1910635      1458.0      81.182722   76.629414
# Johnson High School   3094650     32415.0      80.966394   77.072464
# Pena High School      585858      23754.5      84.044699   83.839917
# Rodriguez High School 2547363     28035.0      80.744686   76.842711
# Shelton High School   1056600      6746.0      83.725724   83.359455
# Thomas High School    1043130     38352.0      83.848930   83.418349
# Wilson High School    1319574     14871.0      83.989488   83.274201
# Wright High School    1049400     25135.5      83.955000   83.682222
#
#                                School ID    size
# school_name           budget
# Bailey High School    3124928        7.0  4976.0
# Cabrera High School   1081356        6.0  1858.0
# Figueroa High School  1884411        1.0  2949.0
# Ford High School      1763916       13.0  2739.0
# Griffin High School   917500         4.0  1468.0
# Hernandez High School 3022020        3.0  4635.0
# Holden High School    248087         8.0   427.0
# Huang High School     1910635        0.0  2917.0
# Johnson High School   3094650       12.0  4761.0
# Pena High School      585858         9.0   962.0
# Rodriguez High School 2547363       11.0  3999.0
# Shelton High School   1056600        2.0  1761.0
# Thomas High School    1043130       14.0  1635.0
# Wilson High School    1319574        5.0  2283.0
# Wright High School    1049400       10.0  1800.0

# %%
# per student budget

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
